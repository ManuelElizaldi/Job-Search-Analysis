# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\Manuel Elizaldi\Desktop\Learning-Testing\Unemployed-Project\JobTracker.xlsx', sheet_name = 'Clean Data')

# %%
df
# Out:
#      Index                                   Position  \
# 0        1               Business System Data Analyst
# 1        2  Associate Analyst, Customer Data (REMOTE)
# 2        3      Analytics, Reporting Analyst - Remote
# 3        4     Alternative Data Analyst - Webscraping
# 4        5                 Financial Planning Analyst
# ..     ...                                        ...
# 521    522                                        NaN
# 522    523                           Data Analyst III
# 523    524       Senior Business Intelligence Analyst
# 524    525                           Business Analyst
# 525    526                               Data Analyst
#
#      Messaged Recruiter or Team                 Date               Status  \
# 0                         False  2023-01-20 00:00:00            No Answer
# 1                         False  2023-01-22 00:00:00   Denied 1 Interview
# 2                         False  2023-01-24 00:00:00               Denied
# 3                         False  2023-01-24 00:00:00            No Answer
# 4                         False  2023-01-24 00:00:00            No Answer
# ..                          ...                  ...                  ...
# 521                        True  2023-12-22 00:00:00  Ghosted 1 Interview
# 522                        True  2023-12-22 00:00:00  Ghosted 1 Interview
# 523                        True  2023-01-11 00:00:00            No Answer
# 524                        True  2024-01-23 00:00:00            No Answer
# 525                        True                    -  Ghosted 1 Interview
#
#      Interviews       Source
# 0             0     LinkedIn
# 1             1     LinkedIn
# 2             0     LinkedIn
# 3             0     LinkedIn
# 4             0     LinkedIn
# ..          ...          ...
# 521           1  Networking
# 522           1  Networking
# 523           0  Networking
# 524           0  Networking
# 525           1   Networking
#
# [526 rows x 7 columns]
